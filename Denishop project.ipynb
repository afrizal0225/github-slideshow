# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_excel(r"C:\Users\user\Desktop\Denishop project\alldata1.xls")
df1 = pd.read_excel(r"C:\Users\user\Desktop\Denishop project\data shoope denishop 3 bulan\SEMUA PENJUALAN BULAN JULI -SEPTEMBER\Order.all.20200701_20200731.xls")
df2 = pd.read_excel(r"C:\Users\user\Desktop\Denishop project\data shoope denishop 3 bulan\SEMUA PENJUALAN BULAN JULI -SEPTEMBER\Order.all.20200801_20200831.xls")
df3 = pd.read_excel(r"C:\Users\user\Desktop\Denishop project\data shoope denishop 3 bulan\SEMUA PENJUALAN BULAN JULI -SEPTEMBER\Order.all.20200901_20200929.xls")
dfiklan1 = pd.read_csv(r"C:\Users\user\Desktop\Denishop project\DATA IKLAN SHOOPE JULI-SEPTEMBER\denigshop.shopee-adwords-stats-product.2020-09-01-2020-09-29.csv")
dfiklan2 = pd.read_excel(r"C:\Users\user\Desktop\Denishop project\DATA IKLAN SHOOPE JULI-SEPTEMBER\alldataiklan.xlsx")

# %%
df
# Out:
#         No. Pesanan Status Pesanan  \
# 0    2007017GGKC3BN        Selesai
# 1    20070189AM8H3X        Selesai
# 2    2007018VEWF3GK        Selesai
# 3    2007018Y30DK12          Batal
# 4    200702A7SEUUVR        Selesai
# ..              ...            ...
# 345  200928VUTDK7UM  Perlu Dikirim
# 346  200928VWUUY1XB          Batal
# 347  20092918PWUJUQ  Perlu Dikirim
# 348  2009292A1UJ50U  Perlu Dikirim
# 349             NaN            NaN
#
#                                      Alasan Pembatalan  \
# 0                                                    -
# 1                                                    -
# 2                                                    -
# 3    Dibatalkan oleh Pembeli. Alasan: Lainnya/ beru...
# 4                                                    -
# ..                                                 ...
# 345                                                  -
# 346           Dibatalkan oleh Pembeli. Alasan: Lainnya
# ...

# %%
dfwaktu = df.groupby(['Waktu Pesa']).sum()

# %%
xvalues = range(len(dfwaktu))

# %%
plt.bar(xvalues, dfwaktu["al Pembayaran"], ec="k")
plt.show()

# %%
df["al Pembayaran"].sum()
# Out:
# 52728391.0

# %%
df['Username (Pembeli)'].nunique()
# Out:
# 274

# %%
df['Nama Produk'].value_counts()
# Out:
# JAKET SWEATER HOODIE DISTRO TREND LINE BALENCIAGA HITAM                                              26
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK JUMPER CASUAL & HYPEBEAST  PREMIUM         13
# KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAOS HYPEBEAST PREMIUM                                    11
# SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARIS PREMIUM BLACK TERLARIS                                9
# JAKET SWEATER HOODIE JUMPER TREND CASUAL DISTRO & SKATE SCREAMOUS RAINBOW BLACK                       8
#                                                                                                      ..
# JAKET SWEATER HOODIE PRIA/WANITA BASTER COLD ORIGINAL CLUB, BLACK, GREEN ARMY , GREEN PREMIUM         1
# JAKET SWEATER HOODIE JUMPER DISTRO 3SECOND TEXT SMALL BLACK, NAVY PREMIUM                             1
# JAKET HOODIE JUMPER HYPEBEAST TREND MARCELO BURLON GRADASI PREMIUM                                    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 21 columns):
# No. Pesanan                       349 non-null object
# Status Pesanan                    349 non-null object
# Alasan Pembatalan                 349 non-null object
# Opsi Pengiriman                   349 non-null object
# Antar ke counter/ pick-up         349 non-null object
# Waktu Pesa                        349 non-null object
# Nama Produk                       349 non-null object
# Nama Variasi                      349 non-null object
# ga Awal                           349 non-null float64
# ga Setelah Diskon                 349 non-null float64
# Jumlah                            349 non-null float64
# al Harga Produk                   349 non-null float64
# al Diskon                         349 non-null float64
# kon Dari Penjual                  349 non-null float64
# kos Kirim Dibayar oleh Pembeli    349 non-null float64
# ...

# %%
df1.head(2)
# Out:
#       No. Pesanan Status Pesanan Alasan Pembatalan  \
# 0  2007017GGKC3BN        Selesai               NaN
# 1  20070189AM8H3X        Selesai               NaN
#
#    Status Pembatalan/ Pengembalian      No. Resi Opsi Pengiriman  \
# 0                              NaN  JP0458811602     J&T Express
# 1                              NaN  JP1895471168     J&T Express
#
#   Antar ke counter/ pick-up  \
# 0          Antar ke Counter
# 1          Antar ke Counter
#
#   Pesanan Harus Dikirimkan Sebelum (Menghindari keterlambatan)  \
# 0                                   2020-07-06 06:17
# 1                                   2020-07-06 13:41
#
#   Waktu Pengiriman Diatur Waktu Pesanan Dibuat  ... Perkiraan Ongkos Kirim  \
# 0        2020-07-01 18:26     2020-07-01 06:17  ...              Rp 14.000
# 1        2020-07-01 18:26     2020-07-01 13:41  ...              Rp 15.000
#
#                                 Catatan dari Pembeli Catatan  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 350 entries, 0 to 349
# Data columns (total 21 columns):
# No. Pesanan                       349 non-null object
# Status Pesanan                    349 non-null object
# Alasan Pembatalan                 349 non-null object
# Opsi Pengiriman                   349 non-null object
# Antar ke counter/ pick-up         349 non-null object
# Waktu Pesa                        349 non-null object
# Nama Produk                       349 non-null object
# Nama Variasi                      349 non-null object
# ga Awal                           349 non-null float64
# ga Setelah Diskon                 349 non-null float64
# Jumlah                            349 non-null float64
# al Harga Produk                   349 non-null float64
# al Diskon                         349 non-null float64
# kon Dari Penjual                  349 non-null float64
# kos Kirim Dibayar oleh Pembeli    349 non-null float64
# ...

# %%
df1['Nama Produk'].value_counts().head(20)
# Out:
# SWEATER HOODIE JUMPER TREND BASTER COLD ORIGINAL HEALT THE WORLD PREMIUM PINK                    4
# JAKET HOODIE ZIPPER SKYBLUE ORIGINAL MOTIF SALUR PREMIUM NAVY,GREY,MAROON,HITAM                  4
# SWEATER CREWNECK TREND CASUAL & HYPEBEAST GAP AUTHENTIC CREAM PREMIUM                            4
# Sweater Hoodie Distro Trend Line Balenciaga Mocca / hitam                                        4
# JAKET SWEATER HOODIE JUMPER TREND CASUAL & HYPEBEAST PULL&BEAR X STARWARS PREMIUM HITAM,PUTIH    4
# JAKET SWEATER HOODIE BASTER COLD ORIGINAL SIG BASIC PREMIUM MAROON                               3
# JAKET SWATER HOODIE JUMPER CASUAL & HYPEBEAST GUCCI DOLLAR PREMIUM WHITE                         3
# Sweater Hoodie Jumper Trend Distro Shining Bright The Trust Black                                3
# SWEATER HOODIE JUMPER BASTER COLD ORIGINAL SIGNATURE PREMIUM GRADASI                             3
# ...

# %%
df2['Nama Produk'].value_counts().head(20)
# Out:
# JAKET SWEATER HOODIE DISTRO TREND LINE BALENCIAGA HITAM                                               13
# KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAOS HYPEBEAST PREMIUM                                      7
# JAKET POLOS CASUAL SWEATER HOODIE JUMPER WARNA PURPLE LIGHT TWO TONE                                   7
# SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARIS PREMIUM BLACK TERLARIS                                 6
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK PREMIUM                                      4
# JAKET SWEATER HOODIE GAP BORDIR AUTHENTIC JUMPER CASUAL & HYPEBEAST PREMIUM ORANGE & KUNING KUNYIT     4
# JAKET SWEATER HOODIE H&M SPONGEBOB JUMPER CASUAL & HYPEBEAST  SMALL PREMIUM PINK                       4
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK JUMPER CASUAL & HYPEBEAST  PREMIUM           4
# SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAST BLACK.,GREY PREMIUM                                    3
# ...

# %%
df3['Nama Produk'].value_counts().head(20)
# Out:
# JAKET SWEATER HOODIE DISTRO TREND LINE BALENCIAGA HITAM                                               13
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK JUMPER CASUAL & HYPEBEAST  PREMIUM           9
# JAKET SWEATER HOODIE JUMPER TREND CASUAL DISTRO & SKATE SCREAMOUS RAINBOW BLACK                        7
# KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAOS HYPEBEAST PREMIUM                                      4
# Jaket hoodie jumper trend Line distro lokal brand ID screamous Black                                   3
# Jaket coach trend Line distro Bandung BGSR premium Black                                               3
# JAKET SWEATER HOODIE H&M SPONGEBOB JUMPER CASUAL & HYPEBEAST  SMALL PREMIUM PINK                       2
# JAKET SWEATER HOODIE BASTER COLD ORIGINAL CLUB CASUAL PREMIUM ORANGE                                   2
# Sweater Crewneck Distro Weekend Offender Olivares Black,Green Premium                                  2
# ...

# %%
df2['Nama Produk'].value_counts().head(20)
# Out:
# JAKET SWEATER HOODIE DISTRO TREND LINE BALENCIAGA HITAM                                               13
# KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAOS HYPEBEAST PREMIUM                                      7
# JAKET POLOS CASUAL SWEATER HOODIE JUMPER WARNA PURPLE LIGHT TWO TONE                                   7
# SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARIS PREMIUM BLACK TERLARIS                                 6
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK PREMIUM                                      4
# JAKET SWEATER HOODIE GAP BORDIR AUTHENTIC JUMPER CASUAL & HYPEBEAST PREMIUM ORANGE & KUNING KUNYIT     4
# JAKET SWEATER HOODIE H&M SPONGEBOB JUMPER CASUAL & HYPEBEAST  SMALL PREMIUM PINK                       4
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK JUMPER CASUAL & HYPEBEAST  PREMIUM           4
# SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAST BLACK.,GREY PREMIUM                                    3
# ...

# %%
df['Nama Produk'].value_counts().head(20)
# Out:
# JAKET SWEATER HOODIE DISTRO TREND LINE BALENCIAGA HITAM                                                 26
# JAKET SWEATER HOODIE A BATHING APE X H&M NASA WHITE,BLACK JUMPER CASUAL & HYPEBEAST  PREMIUM            13
# KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAOS HYPEBEAST PREMIUM                                       11
# SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARIS PREMIUM BLACK TERLARIS                                   9
# JAKET SWEATER HOODIE JUMPER TREND CASUAL DISTRO & SKATE SCREAMOUS RAINBOW BLACK                          8
# JAKET POLOS CASUAL SWEATER HOODIE JUMPER WARNA PURPLE LIGHT TWO TONE                                     7
# JAKET SWEATER HOODIE H&M SPONGEBOB JUMPER CASUAL & HYPEBEAST  SMALL PREMIUM PINK                         6
# SWEATER HOODIE JUMPER TREND BASTER COLD ORIGINAL HEALT THE WORLD PREMIUM PINK                            6
# JAKET HOODIE ZIPPER SKYBLUE ORIGINAL MOTIF SALUR PREMIUM NAVY,GREY,MAROON,HITAM                          5
# ...

# %%
df['Nama Produk'].nunique()
# Out:
# 173

# %%
df['No. Pesanan'].nunique()
# Out:
# 330

# %%
df["Username (Pembeli)"].value_counts().head(11)
# Out:
# -                 20
# sipbuyerid        13
# maratun_naziah     6
# bintorobudiono     4
# wulandarisip4      4
# sweansea98         3
# khayra2812         2
# rafihasan20        2
# jefriokky17        2
# hndhanida          2
# abdika32           2
# Name: Username (Pembeli), dtype: int64

# %%
dfiklan1.head(2)
# Out:
#                                               Urutan  Nama Produk  Status  \
# 0  1\t,"JAKET SWEATER HOODIE UNIQLO X KAWS LIMITE...          NaN     NaN
# 1  2\t,SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WH...          NaN     NaN
#
#    Tanggal Mulai  Tanggal Selesai  Dilihat  Jumlah Klik  Persentase Klik  \
# 0            NaN              NaN      NaN          NaN              NaN
# 1            NaN              NaN      NaN          NaN              NaN
#
#    Jumlah Pesanan  Produk Terjual  Omzet Penjualan  Expense  \
# 0             NaN             NaN              NaN      NaN
# 1             NaN             NaN              NaN      NaN
#
#    Efektifitas Iklan  CIR Urutan1  \
# 0                NaN  NaN     1\t
# 1                NaN  NaN     2\t
#
#                                         Nama Produk1
# 0  "JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED AR...
# 1  SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WHITE ...

# %%
dfiklan1['Urutan1'] = dfiklan1['Urutan'].apply(lambda x : x.split(',')[0])

# %%
dfiklan1.head(1)
# Out:
#                                               Urutan  Nama Produk  Status  \
# 0  1\t,"JAKET SWEATER HOODIE UNIQLO X KAWS LIMITE...          NaN     NaN
#
#    Tanggal Mulai  Tanggal Selesai  Dilihat  Jumlah Klik  Persentase Klik  \
# 0            NaN              NaN      NaN          NaN              NaN
#
#    Jumlah Pesanan  Produk Terjual  Omzet Penjualan  Expense  \
# 0             NaN             NaN              NaN      NaN
#
#    Efektifitas Iklan  CIR Urutan1  \
# 0                NaN  NaN     1\t
#
#                                         Nama Produk1
# 0  "JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED AR...

# %%
dfiklan1['Nama Produk1'] = dfiklan1['Urutan'].apply(lambda x : x.split(',')[1])

# %%
dfiklan1.head(1)
# Out:
#                                               Urutan  Nama Produk  Status  \
# 0  1\t,"JAKET SWEATER HOODIE UNIQLO X KAWS LIMITE...          NaN     NaN
#
#    Tanggal Mulai  Tanggal Selesai  Dilihat  Jumlah Klik  Persentase Klik  \
# 0            NaN              NaN      NaN          NaN              NaN
#
#    Jumlah Pesanan  Produk Terjual  Omzet Penjualan  Expense  \
# 0             NaN             NaN              NaN      NaN
#
#    Efektifitas Iklan  CIR Urutan1  \
# 0                NaN  NaN     1\t
#
#                                         Nama Produk1
# 0  "JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED AR...

# %%
dfiklan1['Status1'] = dfiklan1['Urutan'].apply(lambda x : x.split(',')[2]
# Out:
#   File "<ipython-input-33-b6ac0666d893>", line 1
#     dfiklan1['Status1'] = dfiklan1['Urutan'].apply(lambda x : x.split(',')[2]
#                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
dfiklan1.drop(columns=['Nama Produk', 'Status', 'Dilihat', 'Jumlah Klik', 'Persentase Klik', 'Produk Terjual', 'Tanggal Mulai', 'Tanggal Selesai', 'Omzet Penjualan', 'Expense', 'Efektifitas Iklan', 'CIR', 'Jumlah Pesanan'],axis=1, inplace=True)

# %%
dfiklan1
# Out:
#                                                 Urutan Urutan1  \
# 0    1\t,"JAKET SWEATER HOODIE UNIQLO X KAWS LIMITE...     1\t
# 1    2\t,SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WH...     2\t
# 2    3\t,SWEATER CREWNECK CASUAL & HYPEBEAST KENZO ...     3\t
# 3    4\t,JAKET SWEATER HOODIE DISTRO TREND LINE BAL...     4\t
# 4    5\t,"SWEATER CREWNECK  H&M NASA X BAPE CASUAL ...     5\t
# ..                                                 ...     ...
# 199  200\t,kaos longsleeve ripcurl premium,closed,2...   200\t
# 200  201\t,jaket bb dc navy grey / jaket bulak bali...   201\t
# 201  202\t,Jaket Bomber Double XXL Brown Premium,cl...   202\t
# 202  203\t,bomber fleece djbred navy,closed,07-06-2...   203\t
# 203  204\t,Bomber bape stussy Premium,closed,16-05-...   204\t
#
#                                           Nama Produk1
# 0    "JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED AR...
# 1    SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WHITE ...
# ...

# %%
dfiklan1['Status1'] = dfiklan1['Urutan'].apply(lambda y : y.split(',')[4]
# Out:
#   File "<ipython-input-36-7819fcbc4977>", line 1
#     dfiklan1['Status1'] = dfiklan1['Urutan'].apply(lambda y : y.split(',')[4]
#                                                                              ^
# SyntaxError: unexpected EOF while parsing

# %%
dfiklan2
# Out:
#      Urutan                                        Nama Produk   Status  \
# 0         1  SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAS...  ongoing
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 2         3  JAKET SWEATER HOODIE UNIQLO X KAWS JUMPER CASU...    ended
# 3         4  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 4         5  BOTOL AIR MINUM SILIKON BPA FREE 450ML UNTUK T...    ended
# ..      ...                                                ...      ...
# 607     608                    kaos longsleeve ripcurl premium   closed
# 608     609  jaket bb dc navy grey / jaket bulak balik / ja...   closed
# 609     610              Jaket Bomber Double XXL Brown Premium   closed
# 610     611                          bomber fleece djbred navy   closed
# 611     612                         Bomber bape stussy Premium   closed
#
#            Tanggal Mulai      Tanggal Selesai  Dilihat  Jumlah Klik  \
# ...

# %%
dfiklan2.dtypes
# Out:
# Urutan                 int64
# Nama Produk           object
# Status                object
# Tanggal Mulai         object
# Tanggal Selesai       object
# Dilihat                int64
# Jumlah Klik            int64
# Persentase Klik       object
# Jumlah Pesanan         int64
# Produk Terjual         int64
# Omzet Penjualan      float64
# Expense              float64
# Efektifitas Iklan    float64
# CIR                   object
# dtype: object

# %%
dfiklan2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 612 entries, 0 to 611
# Data columns (total 14 columns):
# Urutan               612 non-null int64
# Nama Produk          612 non-null object
# Status               612 non-null object
# Tanggal Mulai        612 non-null object
# Tanggal Selesai      612 non-null object
# Dilihat              612 non-null int64
# Jumlah Klik          612 non-null int64
# Persentase Klik      612 non-null object
# Jumlah Pesanan       612 non-null int64
# Produk Terjual       612 non-null int64
# Omzet Penjualan      612 non-null float64
# Expense              612 non-null float64
# Efektifitas Iklan    612 non-null float64
# CIR                  612 non-null object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 67.1+ KB

# %%
dfiklan2["Persentase Klik"].sort_values(ascending = False).head(10)
# Out:
# 38     9.63%
# 266    9.52%
# 225    9.23%
# 63     8.45%
# 277    8.33%
# 260    8.33%
# 247    8.11%
# 58     7.69%
# 272    7.14%
# 270    7.14%
# Name: Persentase Klik, dtype: object

# %%
dfklik = dfiklan2.sort_values("Persentase Klik" , ascending = False).head(10)

# %%
dfdilihat = dfiklan2.sort_values("Dilihat" , ascending = False).head(10)

# %%
dfomzet = dfiklan2.sort_values("Omzet Penjualan" , ascending = False).head(10)

# %%
dfomzet.to_excel("dfomzet.xlsx")
dfdilihat.to_excel("dfdilihat.xlsx")
dfklik.to_excel("dfklik.xlsx")

# %%
dfomzet
# Out:
#      Urutan                                        Nama Produk   Status  \
# 207     208  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 412     413  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 432     433  JAKET SWEATER HOODIE A BATHING APE CAMO SPACE ...   paused
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 426     427  JAKET SWEATER HOODIE BASTER COLD ORIGINAL CLUB...  ongoing
# 411     412  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 224     225  JAKET SWEATER HOODIE A BATHING APE X H&M NASA ...  ongoing
# 38       39  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 6         7  JAKET SWEATER HOODIE A BATHING APE X H&M NASA ...  ongoing
# 7         8  SWEATER CREWNECK TREND LINE CASUAL & HYPEBEAST...   closed
#
#            Tanggal Mulai      Tanggal Selesai  Dilihat  Jumlah Klik  \
# 207  2020-01-01 00:00:00            Unlimited     5912          281
# ...

# %%
dfdilihat
# Out:
#      Urutan                                        Nama Produk   Status  \
# 204     205  Sweater Rajut Pria/Wanita Trend Maroon, Navy,B...    ended
# 408     409  JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED ART...  ongoing
# 0         1  SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAS...  ongoing
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 205     206  SWEATER CREWNECK PRIA OVERSIZE TSAFF BLACK ORI...    ended
# 2         3  JAKET SWEATER HOODIE UNIQLO X KAWS JUMPER CASU...    ended
# 206     207  SWEATER CREWNECK CASUAL & HYPEBEAST GUCCI MICK...   paused
# 409     410  SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WHITE ...  ongoing
# 410     411  SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARI...   paused
# 3         4  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
#
#            Tanggal Mulai      Tanggal Selesai  Dilihat  Jumlah Klik  \
# 204     23-06-2020 00:00  2020-11-09 08:37:00    12380          150
# ...

# %%
df['Kota/Kabupaten'].value_counts().head(11)
# Out:
# -                       20
# KOTA JAKARTA UTARA      14
# KOTA BANDUNG            13
# KOTA SURABAYA           12
# KOTA JAKARTA TIMUR      10
# KAB. TANGERANG           9
# KAB. BOGOR               8
# KOTA JAKARTA BARAT       7
# KOTA JAKARTA SELATAN     7
# KAB. DELI SERDANG        6
# KOTA JAMBI               6
# Name: Kota/Kabupaten, dtype: int64

# %%
dfiklan2.sort_values(["CIR"], ascending = False)
# Out:
#      Urutan                                        Nama Produk   Status  \
# 422     423  KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAO...   paused
# 412     413  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 431     432  Jaket hoodie jumper trend Line distro lokal br...  ongoing
# 413     414  KAOS TSHIRT DICKIES LOGO CASUAL HYPEBEAST PREM...   paused
# ..      ...                                                ...      ...
# 210     211  BEST SELLER !! JAKET SWEATER HOODIE WEEKEND OF...  ongoing
# 211     212  JAKET SWEATER HOODIE THANKSINSOMNIA JUMPER DIS...   paused
# 212     213  SWEATER CREWNECK LOCAL BRAND BASTER COLD ORIGI...   paused
# 213     214  SWEATER HOODIE SHINING BRIGHT JUMPER DISTRO & ...    ended
# 611     612                         Bomber bape stussy Premium   closed
#
#            Tanggal Mulai      Tanggal Selesai  Dilihat  Jumlah Klik  \
# ...

# %%
dfCIR = dfiklan2.sort_values(["CIR"], ascending = False)

# %%
dfCIR.to_excel("dfCIR.xlsx")

# %%
dfCIR.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 612 entries, 422 to 611
# Data columns (total 14 columns):
# Urutan               612 non-null int64
# Nama Produk          612 non-null object
# Status               612 non-null object
# Tanggal Mulai        612 non-null object
# Tanggal Selesai      612 non-null object
# Dilihat              612 non-null int64
# Jumlah Klik          612 non-null int64
# Persentase Klik      612 non-null object
# Jumlah Pesanan       612 non-null int64
# Produk Terjual       612 non-null int64
# Omzet Penjualan      612 non-null float64
# Expense              612 non-null float64
# Efektifitas Iklan    612 non-null float64
# CIR                  612 non-null object
# dtypes: float64(3), int64(5), object(6)
# memory usage: 71.7+ KB

# %%
dfiklan2.sort_values(["Jumlah Pesanan"], ascending = False).head(20)
# Out:
#      Urutan                                        Nama Produk   Status  \
# 207     208  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 411     412  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 412     413  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 422     423  KAOS TSHIRT H&M NASA APOLLO NAVY PREMIUM - KAO...   paused
# 38       39  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# 432     433  JAKET SWEATER HOODIE A BATHING APE CAMO SPACE ...   paused
# 0         1  SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAS...  ongoing
# 479     480  JAKET PRIA - JAKET WANITA- FASHION PRIA - FASH...   closed
# 224     225  JAKET SWEATER HOODIE A BATHING APE X H&M NASA ...  ongoing
# 208     209  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 206     207  SWEATER CREWNECK CASUAL & HYPEBEAST GUCCI MICK...   paused
# ...

# %%
dfiklan2.sort_values(["Dilihat"], ascending = False).head(20)
# Out:
#      Urutan                                        Nama Produk   Status  \
# 204     205  Sweater Rajut Pria/Wanita Trend Maroon, Navy,B...    ended
# 408     409  JAKET SWEATER HOODIE UNIQLO X KAWS LIMITED ART...  ongoing
# 0         1  SWEATER CREWNECK UNIQLO X KAWS CASUAL HYPEBEAS...  ongoing
# 1         2  JAKET HOODIE ZIPPER LOCAL BRAND ORIGINAL CASUA...    ended
# 205     206  SWEATER CREWNECK PRIA OVERSIZE TSAFF BLACK ORI...    ended
# 2         3  JAKET SWEATER HOODIE UNIQLO X KAWS JUMPER CASU...    ended
# 206     207  SWEATER CREWNECK CASUAL & HYPEBEAST GUCCI MICK...   paused
# 409     410  SWEATER CREWNECK CASUAL & HYPEBEAST OFF-WHITE ...  ongoing
# 410     411  SWEATER CREWNECK CASUAL & HYPEBEAST KENZO PARI...   paused
# 3         4  SWEATER CREWNECK  H&M NASA X BAPE CASUAL & HYP...  ongoing
# 4         5  BOTOL AIR MINUM SILIKON BPA FREE 450ML UNTUK T...    ended
# 207     208  JAKET SWEATER HOODIE DISTRO TREND LINE BALENCI...  ongoing
# ...
