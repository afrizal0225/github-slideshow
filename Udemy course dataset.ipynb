# %%
import pandas as pd

# %%
data = pd.read_csv(r"C:\Users\user\Desktop\Data Analyst\7. Udemy Courses.csv")

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.subject.unique()
# Out:
# array(['Musical Instruments', 'Business Finance', 'Graphic Design',
#        'Web Development'], dtype=object)

# %%
data["subject"].value_counts()
# Out:
# Web Development        1200
# Business Finance       1199
# Musical Instruments     680
# Graphic Design          603
# Name: subject, dtype: int64

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
datafree = data[data.is_paid == False]

# %%
datafree.course_title.unique()
# Out:
# array(['5 lecciones que todo guitarrista debe tomar',
#        '7 Ways A Beginner Guitarist Can Sound Better, Instantly!',
#        "A beginner`s guide to fingerpicking and strumming guitar'",
#        'A how to guide in HTML',
#        '¡Triunfar en La Bolsa de Valores No Requiere de Experiencia!',
#        'สอนเทรดไบนารี่ อ๊อฟชั่นอย่างง่าย',
#        'Accounting Basics by Hector Garcia, CPA',
#        'Accounting in 60 Minutes - A Brief Introduction',
#        'Acoustic Blues Guitar Lessons', 'Acoustic Guitar Basics',
#        'Adobe Illustrator Course in Urdu Basics Level Training',
#        'Adobe Indesign CC Başlangıç', 'ブルースギター入門',
#        'Angular 2 Routing: Up And Running',
#        'Angular Material - Quickstart', 'Angular Tutorial For Beginners',
#        'AngularJS Authentication: Secure Your App with Auth0',
#        'AngularJS For Beginners',
#        'Apply finance concepts for smart project management',
#        'Aprenda Modelagem 3D com o 123D Design',
# ...

# %%
datapaid = data[data.is_paid == True]

# %%
datapaid.course_title.unique()
# Out:
# array(['#1 Piano Hand Coordination: Play 10th Ballad in Eb Key songs',
#        '#10 Hand Coordination - Transfer Chord Ballad 9 - C & Bb Key',
#        '#12 Hand Coordination: Let your Hands dance with Ballad 9', ...,
#        'Your Second Course on Piano: Two Handed Playing',
#        'Zend Framework 2: Learn the PHP framework ZF2 from scratch',
#        'Zombie Apocalypse Photoshop Actions'], dtype=object)

# %%
datapaid.course_title.nunique()
# Out:
# 3359

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data.course_title.value_counts()
# Out:
# Creating an animated greeting card via Google Slides            3
# Acoustic Blues Guitar Lessons                                   3
# MicroStation - Células                                          2
# CFA Level 2- Quantitative Methods                               2
# Aprende a tocar el acordeón de botones                          2
#                                                                ..
# Trader sur le Forex avec Ichimoku                               1
# Guitar Lessons - Sweep Picking Arpeggio Essentials              1
# Stock Trading Strategies Using a D.A.R.T.                       1
# Intermediate Options trading concepts for Stocks and Options    1
# How To Design A Fortune 500 Logo in Illustrator                 1
# Name: course_title, Length: 3667, dtype: int64

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
data.sort_values("num_subscribers" , ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2230      41295               Learn HTML5 Programming From Scratch    False
# 776       59014                     Coding for Entrepreneurs Basic    False
# 3385     625204                         The Web Developer Bootcamp     True
# 640      173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3316     764164              The Complete Web Developer Course 2.0     True
# ...         ...                                                ...      ...
# 2290    1223240  Learn Pirates of the Caribbean by Ear on the P...     True
# 1267    1258666                Financial Statement Auditing Cycles     True
# 2070    1215926                Kickstarter success in 5 easy steps     True
# 1931    1247992  Introduction to Project Management for Finance...     True
# 3165    1087466  Stop Creditors from Harassing you and Avoid Ba...     True
#
# ...

# %%
data.head(1)
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
#
#   price  num_subscribers  num_reviews  num_lectures       level  \
# 0    35             3137           18            68  All Levels
#
#   content_duration   published_timestamp              subject
# 0        1.5 hours  2014-09-18T05:07:05Z  Musical Instruments

# %%
datagd = data[data.subject == "Graphic Design"]

# %%
datagd.sort_values("num_subscribers" , ascending = False)
# Out:
#       course_id                                       course_title  is_paid  \
# 2726     348116  Photoshop In-Depth: Master all of Photoshop's ...    False
# 1218      17349  Figure Drawing From Life Using The Reilly Tech...    False
# 2904     399938      Professional Logo Design in Adobe Illustrator    False
# 2722     820194  Photoshop for Entrepreneurs - Design 11 Practi...     True
# 2470     249126                            Logo Design Essentials      True
# ...         ...                                                ...      ...
# 2900     995384  Professional Business Logo Design Using Free O...     True
# 2702    1137738                    Photoshop - Creación de Efectos     True
# 2703    1185898                  Photoshop - Creación de Efectos 2     True
# 1132    1047408                          Easy Coloring Book Design     True
# 476     1252410  Beginners Guide to Kindle Ebook Covers Design ...     True
#
# ...

# %%
data[(data.subject == "Graphic Design") & (data.price > "100")]
# Out:
#       course_id                                       course_title  is_paid  \
# 8        206592  :::Beginners Guide To Creating Amazing Images ...     True
# 20      1165268  15  Motion Graphic Elements in After Effect (S...     True
# 35      1164876  3DS MAX - Learn 3Ds MAX tutorial for Beginners...     True
# 39       599652                     48 Logo Designs and Techniques     True
# 52       794036       8 Stunden professionelles Cinema 4D Training     True
# ...         ...                                                ...      ...
# 3568     133968                 Web Elements Design With Photoshop     True
# 3588    1131780  Whiteboard Animation, Beginner To Expert - In ...     True
# 3639    1122306         Wordpress: Comment utiliser le thème FABLE     True
# 3671     144222  YOU can Draw, Shade and Paint a Mixed Media Gi...     True
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data[data.course_title.str.contains('Python')]
# Out:
#       course_id                                       course_title  is_paid  \
# 216      599504  Advanced Scalable Python Web Development Using...     True
# 777       47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 814      631128  Complete Python Web Course: Build 8 Python Web...     True
# 842      186096  Core: A Web App Reference Guide for Django, Py...     True
# 1400     394832  Fun and creative web engineering with Python a...    False
# 1932    1038538            Introduction to QGIS Python Programming     True
# 1969     902888          Investment Portfolio Analysis with Python     True
# 2294     391546        Learn Python and Django: Payment Processing     True
# 2295    1063722            Learn Python Django - A Hands-On Course     True
# 2341     546848  Learn to code in Python and learn Adobe Photos...     True
# 2906     368340    Professional Python Web Development Using Flask     True
# ...

# %%
data[data.course_title.str.contains('Python')].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29 entries, 216 to 3574
# Data columns (total 11 columns):
# course_id              29 non-null int64
# course_title           29 non-null object
# is_paid                29 non-null bool
# price                  29 non-null object
# num_subscribers        29 non-null int64
# num_reviews            29 non-null int64
# num_lectures           29 non-null int64
# level                  29 non-null object
# content_duration       29 non-null object
# published_timestamp    29 non-null object
# subject                29 non-null object
# dtypes: bool(1), int64(4), object(6)
# memory usage: 2.5+ KB

# %%
len(data[data.course_title.str.contains('Python')])
# Out:
# 29

# %%
data.dtypes
# Out:
# course_id               int64
# course_title           object
# is_paid                  bool
# price                  object
# num_subscribers         int64
# num_reviews             int64
# num_lectures            int64
# level                  object
# content_duration       object
# published_timestamp    object
# subject                object
# dtype: object

# %%
data.head()
# Out:
#    course_id                                       course_title  is_paid  \
# 0     288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1    1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2    1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3    1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4    1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
#
#   price  num_subscribers  num_reviews  num_lectures               level  \
# 0    35             3137           18            68          All Levels
# 1    75             1593            1            41  Intermediate Level
# 2    75              482            1            47  Intermediate Level
# 3    75              850            3            43  Intermediate Level
# 4    75              940            3            32  Intermediate Level
#
#   content_duration   published_timestamp              subject
# ...

# %%
data["published_timestamp"]=pd.to_datetime(data.published_timestamp)

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# is_paid                               bool
# price                               object
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                    object
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data["year"] = data["published_timestamp"].dt.year

# %%
data.drop(columns = ["head"], inplace = True)

# %%
data
# Out:
#       course_id                                       course_title  is_paid  \
# 0        288942  #1 Piano Hand Coordination: Play 10th Ballad i...     True
# 1       1170074  #10 Hand Coordination - Transfer Chord Ballad ...     True
# 2       1193886  #12 Hand Coordination: Let your Hands dance wi...     True
# 3       1116700  #4 Piano Hand Coordination: Fun Piano Runs in ...     True
# 4       1120410  #5  Piano Hand Coordination:  Piano Runs in 2 ...     True
# ...         ...                                                ...      ...
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
# 3680    1225194  Zoho Books Gestion Financière d'Entreprise pas...    False
# 3681     964478                Zombie Apocalypse Photoshop Actions     True
#
# ...

# %%
data[data.year == 2015]
# Out:
#       course_id                                       course_title  is_paid  \
# 10       591880  1 - Concepts of Statistics For Beginners Step ...     True
# 16       302450        10 Numbers Every Business Owner Should Know     True
# 19       384928  101 Blues riffs - learn how the harmonica supe...     True
# 23       550842  16 Guitar Chords to Jam With - (Beginner - Int...     True
# 26       486240      2 Easy Steps To Investment And Avoiding Traps     True
# ...         ...                                                ...      ...
# 3675     551170                         Your First Course on Piano     True
# 3676     498488  Your First Successful Forex Trades - With Case...     True
# 3677     328960  Your Own Site in 45 Min: The Complete Wordpres...     True
# 3678     552700    Your Second Course on Piano: Two Handed Playing     True
# 3679     631754  Zend Framework 2: Learn the PHP framework ZF2 ...     True
#
# ...

# %%
data.level.unique()
# Out:
# array(['All Levels', 'Intermediate Level', 'Beginner Level',
#        'Expert Level'], dtype=object)

# %%
data.groupby('level')['num_subscribers'].max()
# Out:
# level
# All Levels            268923
# Beginner Level        161029
# Expert Level            5172
# Intermediate Level     29167
# Name: num_subscribers, dtype: int64
